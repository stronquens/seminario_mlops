# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import ElasticNet
from sklearn.datasets import load_boston

#----------------------------------------- DVC
import mlflow
import mlflow.sklearn

import dvc.api

path='data/boston_df.csv'
repo='C:/Users/Armando/Desktop/ITI/INDDIS/dvc_boston'
version='v1'

data_url = dvc.api.get_url(
    path=path,
    repo=repo,
    rev=version
)

mlflow.set_tracking_uri("http://localhost:5000")
#warnings.filterwarnings("ignore")
np.random.seed(40)


mlflow.set_experiment('demo')
#-------------------------- DVC

#data = load_boston()
#df = pd.DataFrame(data.data, columns=data.feature_names)
df = pd.read_csv(data_url, sep=",")

# Log data params
mlflow.log_param('data_url', data_url)
mlflow.log_param('data_version', version)
mlflow.log_param('input_rows', df.shape[0])
mlflow.log_param('input_cols', df.shape[1])

#------------------------------------------

xtest, xtrain, ytest, ytrain = train_test_split(df.drop(['CRIM'],axis=1), df['CRIM'])



# ------------------------------------------- DVC 23:00
# cols_x = pd.DataFrame(list(xtrain.columns))
# cols_x.to_csv('./features.csv', header=False, index=False)
# mlflow.log_artifact('features.csv')

# cols_y = pd.DataFrame(list(ytrain.columns))
# cols_y.to_csv('./targets.csv', header=False, index=False)
# mlflow.log_artifact('targets.csv')


#-------------------------------------------




en = ElasticNet()

def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2

def train(alpha,l1_ratio):
    with mlflow.start_run():
            lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio)
            lr.fit(xtrain, ytrain)

            predicted_qualities = lr.predict(xtest)

            (rmse, mae, r2) = eval_metrics(ytest, predicted_qualities)

            print("Elasticnet model (alpha=%f, l1_ratio=%f):" % (alpha, l1_ratio))
            print("  RMSE: %s" % rmse)
            print("  MAE: %s" % mae)
            print("  R2: %s" % r2)

            mlflow.log_param("alpha", alpha)
            mlflow.log_param("l1_ratio", l1_ratio)
            mlflow.log_metric("rmse", rmse)
            mlflow.log_metric("r2", r2)
            mlflow.log_metric("mae", mae)

            mlflow.sklearn.log_model(lr, "model")

#alpha = np.arange(0,5,0.1)
alpha = 0.5
l1_ratio = 0.5

for a in alpha:
    train(a,l1_ratio)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6952/113582110.py in <module>
#      49 cols_x = pd.DataFrame(list(xtrain.columns))
#      50 cols_x.to_csv('./features.csv', header=False, index=False)
# ---> 51 mlflow.log_artifact('features.csv')
#      52
#      53 cols_y = pd.DataFrame(list(ytrain.columns))
#
# ~\.conda\envs\master_ciencia_datos_21\lib\site-packages\mlflow\tracking\fluent.py in log_artifact(local_path, artifact_path)
#     549     """
#     550     run_id = _get_or_start_run().info.run_id
# --> 551     MlflowClient().log_artifact(run_id, local_path, artifact_path)
#     552
#     553
#
# ~\.conda\envs\master_ciencia_datos_21\lib\site-packages\mlflow\tracking\client.py in log_artifact(self, run_id, local_path, artifact_path)
#     929             is_dir: False
#     930         """
# ...

# %%
# import pandas as pd 
# import dvc.api

# path='data/boston_df.csv'
# repo='C:/Users/Armando/Desktop/ITI/INDDIS/dvc_boston'
# version='v2'

# data_url = dvc.api.get_url(
#     path=path,
#     repo=repo,
#     rev=version
# )
# df = pd.read_csv(data_url, sep=",")
# df
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0   0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1   0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2   0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3   0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4   0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..      ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 95  0.12204   0.0   2.89   0.0  0.445  6.625  57.8  3.4952  2.0  276.0
# 96  0.11504   0.0   2.89   0.0  0.445  6.163  69.6  3.4952  2.0  276.0
# 97  0.12083   0.0   2.89   0.0  0.445  8.069  76.0  3.4952  2.0  276.0
# 98  0.08187   0.0   2.89   0.0  0.445  7.820  36.9  3.4952  2.0  276.0
# 99  0.06860   0.0   2.89   0.0  0.445  7.416  62.5  3.4952  2.0  276.0
#
#     PTRATIO       B  LSTAT
# 0      15.3  396.90   4.98
# 1      17.8  396.90   9.14
# 2      17.8  392.83   4.03
# ...
